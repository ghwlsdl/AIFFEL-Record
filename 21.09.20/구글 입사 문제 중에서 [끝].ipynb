# %%
1부터 10,000까지 8이라는 숫자가 총 몇번 나오는가?

8이 포함되어 있는 숫자의 갯수를 카운팅 하는 것이 아니라 8이라는 숫자를 모두 카운팅 해야 한다.
(※ 예를들어 8808은 3, 8888은 4로 카운팅 해야 함)

# %%
N=int(input()) # N 함수 만들기

for i in range(N+1): #범위 지정
  if '8' in str(i): # 8 숫자 찾기
    print(i)
# Out:
# 10000
# 8
# 18
# 28
# 38
# 48
# 58
# 68
# 78
# 80
# 81
# 82
# 83
# 84
# 85
# 86
# 87
# 88
# 89
# 98
# 108
# 118
# 128
# 138
# 148
# 158
# 168
# 178
# 180
# 181
# 182
# 183
# 184
# 185
# 186
# 187
# 188
# 189
# 198
# 208
# 218
# 228
# 238
# 248
# 258
# 268
# 278
# 280
# 281
# 282
# 283
# 284
# 285
# 286
# 287
# 288
# 289
# 298
# 308
# 318
# 328
# 338
# 348
# 358
# 368
# 378
# 380
# 381
# 382
# 383
# 384
# 385
# 386
# 387
# 388
# 389
# 398
# 408
# 418
# 428
# 438
# 448
# 458
# 468
# 478
# 480
# 481
# 482
# 483
# 484
# 485
# 486
# 487
# 488
# 489
# 498
# 508
# 518
# 528
# 538
# 548
# 558
# 568
# 578
# 580
# 581
# 582
# 583
# 584
# 585
# 586
# 587
# 588
# 589
# 598
# 608
# 618
# 628
# 638
# 648
# 658
# 668
# 678
# 680
# 681
# 682
# 683
# 684
# 685
# 686
# 687
# 688
# 689
# 698
# 708
# 718
# 728
# 738
# 748
# 758
# 768
# 778
# 780
# 781
# 782
# 783
# 784
# 785
# 786
# 787
# 788
# 789
# 798
# 800
# 801
# 802
# 803
# 804
# 805
# 806
# 807
# 808
# 809
# 810
# 811
# 812
# 813
# 814
# 815
# ...

# %%
0008 -> 1000개 -> 4000개??
0080
0800
8000

# %%
count = 0 # 함수 지정
for i in range(1, 10001): # 범위 지정
     count+= str(i).count("8") # i 중에 8 들어간 거 카운팅
print(count)
# Out:
# 4000
